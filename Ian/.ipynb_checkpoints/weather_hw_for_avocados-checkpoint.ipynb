# %% [markdown]
# ## WeatherPy
# Analysis
#
# •	Temperatures are generally highest from -20 to 40 degrees in latitude and steadily decline as the distance away from this hotter range increases.    The findings from the plotted data jibes with our intuitive sense of where the hottest parts of the earth are.  The described range in latitude of hottest parts of the world covers from southern Africa to the northern Mediterranean and from northern Australia to central Japan.
# •	The relationship between humidity and latitude is not as obvious as in the temperature vs latitude, but several trends are apparent.  The 0 to 20 and 60 to 80 degrees of latitude ranges are on average the most humid.   These observations are not surprising because they encompass tropical zones and far northern North America and Eurasia which tend to be very humid in the late summer.   Overall, the humidity is not as clearly correlated with latitude as temperature is and most latitudes plotted can have high humidity.
# •	Wind speed measured in miles per hour shows that moderate wind speeds appear at almost any latitude.  The highest wind speeds, however, appear at and beyond 60 degrees north.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import datetime
today = datetime.date.today()
# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
# testing size
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
#print(lat_lng)
# Identify nearest city latitude and longitude
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
#print(len(cities))
#print(cities)

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# %%
# Alternative API call structure / Save config information
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"


# Build query URL
query_url = url + "appid=" + api_key + "&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=288d202524f103270fcd4898469239ad&q=

# %%
# set up lists to hold reponse info
lat = []
lng = []
temp = []
humid = []
cloudy = []
windy = []
legit_cities = []
countries = []
date = []
i = -1
#print(cities)
response = requests.get(query_url + city).json()
#print(response)
# Loop through list of cities and request data on each
print("Beginning Data Retrieval\n----------------------------")
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        humid.append(response['main']['humidity'])
        cloudy.append(response['clouds']['all'])
        windy.append(response['wind']['speed'])
        legit_cities.append(response['name'])
        countries.append(response['sys']['country'])
        date.append(response['dt'])
        i = i + 1
        print("Retrieving Results for Index " + str(i) + ': ' + city.title())
        print("Data available for: " + city.title())
        print("Adding to dataframe...")
        print("----------------------------")
        
        
    except:
        pass
        i = i + 1
        print("Retrieving Results for Index " + str(i) + ': ' + city.title())
        print("Data not available for: " + city.title())
        print("Skipping...")
        print("----------------------------")

#print(f"The latitude information received is: {lat}")
#print(f"The temperature information received is: {temp}")
#print(legit_cities)
#print(len(legit_cities))
#print(len(lat))
#print(len(temp))
# Out:
# Beginning Data Retrieval
# ----------------------------
# Retrieving Results for Index 0: Okhotsk
# Data available for: Okhotsk
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 1: Rungata
# Data not available for: Rungata
# Skipping...
# ----------------------------
# Retrieving Results for Index 2: Thaton
# Data available for: Thaton
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 3: Yellowknife
# Data available for: Yellowknife
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 4: Avera
# Data available for: Avera
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 5: Georgetown
# Data available for: Georgetown
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 6: Paka
# Data available for: Paka
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 7: Ushuaia
# Data available for: Ushuaia
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 8: Guapiacu
# Data available for: Guapiacu
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 9: Alofi
# Data available for: Alofi
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 10: Sentyabrskiy
# Data not available for: Sentyabrskiy
# Skipping...
# ----------------------------
# Retrieving Results for Index 11: Isangel
# Data available for: Isangel
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 12: Bluff
# Data available for: Bluff
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 13: Puerto Ayora
# Data available for: Puerto Ayora
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 14: Ilulissat
# Data available for: Ilulissat
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 15: Torbay
# Data available for: Torbay
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 16: Duma
# Data available for: Duma
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 17: Saint-Philippe
# Data available for: Saint-Philippe
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 18: Taolanaro
# Data not available for: Taolanaro
# Skipping...
# ----------------------------
# Retrieving Results for Index 19: Sitka
# Data available for: Sitka
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 20: Acarau
# Data not available for: Acarau
# Skipping...
# ----------------------------
# Retrieving Results for Index 21: Tuktoyaktuk
# Data available for: Tuktoyaktuk
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 263: Nizhneyansk
# Data not available for: Nizhneyansk
# Skipping...
# ----------------------------
# Retrieving Results for Index 264: Hit
# Data available for: Hit
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 265: Padang
# Data available for: Padang
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 266: Hirara
# Data available for: Hirara
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 267: Mogadishu
# Data available for: Mogadishu
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 268: Rio Gallegos
# Data available for: Rio Gallegos
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 269: Souillac
# Data available for: Souillac
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 270: Oranjemund
# Data available for: Oranjemund
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 271: Chuy
# Data available for: Chuy
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 272: Klaksvik
# Data available for: Klaksvik
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 273: Sochi
# Data available for: Sochi
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 274: Betioky
# Data not available for: Betioky
# Skipping...
# ----------------------------
# Retrieving Results for Index 275: Henties Bay
# Data available for: Henties Bay
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 276: Shchelyayur
# Data not available for: Shchelyayur
# Skipping...
# ----------------------------
# Retrieving Results for Index 277: Milkovo
# Data available for: Milkovo
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 278: San Cristobal
# Data available for: San Cristobal
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 279: Buala
# Data available for: Buala
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 280: Ribeira Grande
# Data available for: Ribeira Grande
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 281: Mergui
# Data not available for: Mergui
# Skipping...
# ----------------------------
# Retrieving Results for Index 282: Daugai
# Data available for: Daugai
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 283: Luderitz
# Data available for: Luderitz
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 284: Bauchi
# Data available for: Bauchi
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 285: Soc Trang
# Data available for: Soc Trang
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 286: Cabo San Lucas
# Data available for: Cabo San Lucas
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 287: Libourne
# Data available for: Libourne
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 288: Benito Juarez
# Data available for: Benito Juarez
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 289: Port Blair
# Data available for: Port Blair
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 290: Kashi
# Data not available for: Kashi
# Skipping...
# ----------------------------
# Retrieving Results for Index 291: Nhulunbuy
# Data available for: Nhulunbuy
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 292: Asau
# Data not available for: Asau
# Skipping...
# ----------------------------
# Retrieving Results for Index 293: Golden
# Data available for: Golden
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 294: Vung Tau
# Data available for: Vung Tau
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 295: La Ronge
# Data available for: La Ronge
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 296: Labutta
# Data not available for: Labutta
# Skipping...
# ----------------------------
# Retrieving Results for Index 297: Mizdah
# Data available for: Mizdah
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 298: Chardara
# Data not available for: Chardara
# Skipping...
# ----------------------------
# Retrieving Results for Index 299: Lasa
# Data available for: Lasa
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 300: Kalga
# Data available for: Kalga
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 301: Bar Harbor
# Data available for: Bar Harbor
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 302: Banda Aceh
# Data available for: Banda Aceh
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 303: Faya
# Data available for: Faya
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 304: Clovis
# Data available for: Clovis
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 305: Siniscola
# Data available for: Siniscola
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 306: Tateyama
# Data available for: Tateyama
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 307: Coihaique
# Data available for: Coihaique
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 308: Dicabisagan
# Data available for: Dicabisagan
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 309: Geraldton
# Data available for: Geraldton
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 310: Sabha
# Data available for: Sabha
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 311: Valdivia
# Data available for: Valdivia
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 312: Hudson Bay
# Data available for: Hudson Bay
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 313: Sokolo
# Data available for: Sokolo
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 314: Korla
# Data not available for: Korla
# Skipping...
# ----------------------------
# Retrieving Results for Index 315: Porto Novo
# Data available for: Porto Novo
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 316: Banepa
# Data available for: Banepa
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 317: Victoria Point
# Data available for: Victoria Point
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 318: Ust-Barguzin
# Data available for: Ust-Barguzin
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 319: Kopayhorod
# Data available for: Kopayhorod
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 320: Sola
# Data available for: Sola
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 321: Taoudenni
# Data available for: Taoudenni
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 322: Waddan
# Data available for: Waddan
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 323: Puerto Escondido
# Data available for: Puerto Escondido
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 387: Talnakh
# Data available for: Talnakh
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 388: La Orilla
# ...
# Data available for: Shubarshi
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 469: Sur
# Data available for: Sur
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 470: Tabuk
# Data available for: Tabuk
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 471: Mangaluru
# Data available for: Mangaluru
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 472: Olinda
# Data available for: Olinda
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 473: Kuroiso
# Data available for: Kuroiso
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 474: Meadow Lake
# Data available for: Meadow Lake
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 475: Aquiraz
# Data available for: Aquiraz
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 476: Lianzhou
# Data available for: Lianzhou
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 477: Karamea
# Data not available for: Karamea
# Skipping...
# ----------------------------
# Retrieving Results for Index 478: Broome
# Data available for: Broome
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 479: Igrim
# Data available for: Igrim
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 480: Harper
# Data available for: Harper
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 481: Aklavik
# Data available for: Aklavik
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 482: Kosa
# Data available for: Kosa
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 483: Ngunguru
# Data available for: Ngunguru
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 484: Pisco
# Data available for: Pisco
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 485: Port-Gentil
# Data available for: Port-Gentil
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 486: Japura
# Data available for: Japura
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 487: Micheweni
# Data available for: Micheweni
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 488: Mbandaka
# Data available for: Mbandaka
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 489: Leningradskiy
# Data available for: Leningradskiy
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 490: Dublin
# Data available for: Dublin
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 491: Bahce
# Data available for: Bahce
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 492: Ilhabela
# Data available for: Ilhabela
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 493: Nurota
# Data available for: Nurota
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 494: Makakilo City
# Data available for: Makakilo City
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 495: Poum
# Data available for: Poum
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 496: Codrington
# Data available for: Codrington
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 497: Bacuit
# Data not available for: Bacuit
# Skipping...
# ----------------------------
# Retrieving Results for Index 498: Maturin
# Data available for: Maturin
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 499: Pahrump
# Data available for: Pahrump
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 500: Levokumka
# Data available for: Levokumka
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 501: Tabiauea
# Data not available for: Tabiauea
# Skipping...
# ----------------------------
# Retrieving Results for Index 502: Ziyamet
# Data not available for: Ziyamet
# Skipping...
# ----------------------------
# Retrieving Results for Index 503: Warqla
# Data not available for: Warqla
# Skipping...
# ----------------------------
# Retrieving Results for Index 504: Sobolevo
# Data available for: Sobolevo
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 505: Umzimvubu
# Data not available for: Umzimvubu
# Skipping...
# ----------------------------
# Retrieving Results for Index 506: Griffith
# Data available for: Griffith
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 507: Acapulco
# Data available for: Acapulco
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 508: Koygorodok
# Data available for: Koygorodok
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 509: Sergeyevka
# Data available for: Sergeyevka
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 510: San Jeronimo
# Data available for: San Jeronimo
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 511: Acajutla
# Data available for: Acajutla
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 512: Wharton
# Data available for: Wharton
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 513: Guanica
# Data available for: Guanica
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 514: Shelopugino
# Data available for: Shelopugino
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 515: Ulaangom
# Data available for: Ulaangom
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 516: Asyut
# Data available for: Asyut
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 517: Deer Lake
# Data available for: Deer Lake
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 518: Tahe
# Data available for: Tahe
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 519: Bourail
# Data available for: Bourail
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 520: Meyungs
# Data not available for: Meyungs
# Skipping...
# ----------------------------
# Retrieving Results for Index 521: Trairi
# Data available for: Trairi
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 522: Eyl
# Data available for: Eyl
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 523: Pudozh
# Data available for: Pudozh
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 524: Oussouye
# Data available for: Oussouye
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 525: Balkhash
# Data available for: Balkhash
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 526: Ji-Parana
# Data not available for: Ji-Parana
# Skipping...
# ----------------------------
# Retrieving Results for Index 527: Greenfield
# Data available for: Greenfield
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 528: Port Macquarie
# Data available for: Port Macquarie
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 529: Twentynine Palms
# Data available for: Twentynine Palms
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 530: Mabaruma
# Data available for: Mabaruma
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 531: Arman
# Data available for: Arman
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 532: Baneh
# Data available for: Baneh
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 533: Hofn
# Data available for: Hofn
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 534: Igdir
# Data available for: Igdir
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 535: Uwayl
# Data not available for: Uwayl
# Skipping...
# ----------------------------
# Retrieving Results for Index 536: Bairiki
# Data not available for: Bairiki
# Skipping...
# ----------------------------
# Retrieving Results for Index 537: Ludza
# Data available for: Ludza
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 538: Ust-Kuyga
# Data available for: Ust-Kuyga
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 539: Dzhusaly
# Data not available for: Dzhusaly
# Skipping...
# ----------------------------
# Retrieving Results for Index 540: Lata
# Data available for: Lata
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 541: Kirovskiy
# Data available for: Kirovskiy
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 542: Saldanha
# Data available for: Saldanha
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 543: Two Hills
# Data available for: Two Hills
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 544: Coquimbo
# Data available for: Coquimbo
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 545: Turka
# Data available for: Turka
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 546: Exeter
# Data available for: Exeter
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 547: Navolato
# Data available for: Navolato
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 548: Loum
# Data available for: Loum
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 549: Kayes
# Data available for: Kayes
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 550: Redondela
# Data available for: Redondela
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 551: Mamallapuram
# Data available for: Mamallapuram
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 552: Jasper
# Data available for: Jasper
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 553: Ville-Marie
# Data available for: Ville-Marie
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 554: Suzun
# Data available for: Suzun
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 555: Xunchang
# Data available for: Xunchang
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 556: Qibili
# Data not available for: Qibili
# Skipping...
# ----------------------------
# Retrieving Results for Index 557: Tyup
# Data available for: Tyup
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 558: Nuuk
# Data available for: Nuuk
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 559: Martapura
# Data available for: Martapura
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 560: Algeciras
# Data available for: Algeciras
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 561: Tumannyy
# Data not available for: Tumannyy
# Skipping...
# ----------------------------
# Retrieving Results for Index 562: Sao Joao Da Barra
# Data available for: Sao Joao Da Barra
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 563: Lakes Entrance
# Data available for: Lakes Entrance
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 564: Katete
# Data available for: Katete
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 565: Honiara
# Data available for: Honiara
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 566: Arica
# Data available for: Arica
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 567: Baturinskaya
# Data available for: Baturinskaya
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 568: Belmonte
# Data available for: Belmonte
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 569: Mme
# Data not available for: Mme
# Skipping...
# ----------------------------
# Retrieving Results for Index 570: Mareeba
# Data available for: Mareeba
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 571: Gat
# Data available for: Gat
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 572: Iqaluit
# Data available for: Iqaluit
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 573: Muravlenko
# Data available for: Muravlenko
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 574: Paamiut
# Data available for: Paamiut
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 575: Kurilsk
# Data available for: Kurilsk
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 576: Hambantota
# Data available for: Hambantota
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 577: Conde
# Data available for: Conde
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 578: Diu
# Data available for: Diu
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 579: Celestun
# Data available for: Celestun
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 580: Tagusao
# Data available for: Tagusao
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 581: Santa Isabel Do Rio Negro
# Data available for: Santa Isabel Do Rio Negro
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 582: Woodstock
# Data available for: Woodstock
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 583: Sandwick
# Data available for: Sandwick
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 584: Kaka
# Data available for: Kaka
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 585: Sampang
# Data available for: Sampang
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 586: Bagn
# Data available for: Bagn
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 587: Rovaniemi
# Data available for: Rovaniemi
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 588: Muli
# Data available for: Muli
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 589: Zhigansk
# Data available for: Zhigansk
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 590: Fremont
# Data available for: Fremont
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 591: Dumas
# Data available for: Dumas
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 592: Tarakan
# Data available for: Tarakan
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 593: Qostanay
# Data available for: Qostanay
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 594: Wanaka
# Data available for: Wanaka
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 595: Sosva
# Data available for: Sosva
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 596: Mozarlandia
# Data available for: Mozarlandia
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 597: Wajima
# Data available for: Wajima
# Adding to dataframe...
# ----------------------------
# Retrieving Results for Index 598: Amberley
# Data available for: Amberley
# Adding to dataframe...
# ----------------------------

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "City": legit_cities,
    "Country":countries,
    "Lat": lat,
    "Lng": lng,
    "Temp": temp,
    "Humidity": humid,
    "Cloudiness": cloudy,
    "Wind Speed": windy,
    "Date": date
}
weather_data = pd.DataFrame(weather_dict)
weather_data.to_csv('output_data/cities_df.csv')
weather_data.head(15)
# Out:
#             City Country    Lat     Lng   Temp  Humidity  Cloudiness  \
# 0        Okhotsk      RU  59.36  143.24  53.18       100          92
# 1         Thaton      MM  16.91   97.37  75.59       100          92
# 2    Yellowknife      CA  62.45 -114.38  57.20        71          75
# 3          Avera      US  33.19  -82.53  92.01        43          40
# 4     Georgetown      GY   6.80  -58.16  84.23        74           8
# 5           Paka      HR  45.29   18.06  68.00        88           0
# 6        Ushuaia      AR -54.81  -68.31  42.01        56          75
# 7       Guapiacu      BR -20.80  -49.22  93.20        18          20
# 8          Alofi      NU -19.06 -169.92  77.00        88          40
# 9        Isangel      VU -19.55  169.27  72.62       100           0
# 10         Bluff      AU -23.58  149.07  61.28        52           0
# 11  Puerto Ayora      EC  -0.74  -90.35  82.40        51          20
# 12     Ilulissat      GL  69.22  -51.10  39.20        80          75
# 13        Torbay      CA  47.66  -52.73  51.80        87          90
# 14          Duma      SY  33.57   36.40  77.00        61           0
#
#     Wind Speed        Date
# 0         3.96  1535748810
# 1        16.60  1535749308
# 2        19.46  1535745600
# 3         5.82  1535747700
# 4         8.10  1535749157
# 5         2.24  1535747400
# 6         4.70  1535745600
# 7         3.36  1535745600
# 8        13.87  1535745600
# 9        10.00  1535749401
# 10        5.75  1535749458
# 11       24.16  1535745600
# 12        4.70  1535745000
# 13       23.04  1535745600
# 14       11.41  1535749200

# %%
#create date stamp 
new_date = weather_data['Date'].mean()
graph_date = datetime.datetime.fromtimestamp(new_date)
datefinal = graph_date.strftime('%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3cc9c67357bf> in <module>()
#       1 #create date stamp
# ----> 2 new_date = weather_data['Date'].mean()
#       3 graph_date = datetime.datetime.fromtimestamp(new_date)
#       4 datefinal = graph_date.strftime('%Y-%m-%d')
#       5 datefinal
#
# NameError: name 'weather_data' is not defined

# %%
# * Temperature (F) vs. Latitude
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Temp"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Temperature" + ' (Date: ' + datefinal + ')')
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/TemperaturevsLatitude.png", dpi = 900, linewidth=1)

# Show plot
plt.show()

# %%
# Humidity (%) vs. Latitude
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity" +  ' (Date: ' + datefinal + ')')
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/HumidityvsLatitude.png", dpi = 900, linewidth=1)

# Show plot
plt.show()

# %%
# Humidity (%) vs. Latitude
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness" + ' (Date: ' + datefinal + ')')
plt.ylabel("% Sky Clouded")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/CloudinessvsLatitude.png", dpi = 900, linewidth=1)

# Show plot
plt.show()

# %%
# Humidity (%) vs. Latitude
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs Windiness"  + ' (Date: ' + datefinal + ')')
plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/WindinessvsLatitude.png", dpi = 900, linewidth=1)

# Show plot
plt.show()
